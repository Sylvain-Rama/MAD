# %%
import sys
import os
sys.path.append("../")

# %%
os.getcwd(), sys.path
# Out:
# ('g:\\code\\MAD\\src\\notebooks',
#  ['C:\\Users\\Syla\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip',
#   'C:\\Users\\Syla\\AppData\\Local\\Programs\\Python\\Python312\\DLLs',
#   'C:\\Users\\Syla\\AppData\\Local\\Programs\\Python\\Python312\\Lib',
#   'C:\\Users\\Syla\\AppData\\Local\\Programs\\Python\\Python312',
#   'g:\\code\\MAD\\.venv',
#   '',
#   'g:\\code\\MAD\\.venv\\Lib\\site-packages',
#   'src/',
#   'src/',
#   '/src/',
#   '/src/objs',
#   '../src/objs',
#   '../'])

# %%
import numpy as np

from objs.common_schemas import MovableObject

# %%
np.array([1, 1]) + np.array([2, 2, 2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 np.array([1, 1]) + np.array([2, 2, 2])
#
# ValueError: operands could not be broadcast together with shapes (2,) (3,)
