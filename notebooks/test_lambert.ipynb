# %%
from lamberthub import vallado2013
import numpy as np
from mad.objs.planets import Planet, PlanetConfig
from mad.objs.constants import EARTH_SETTINGS

# %%
earth = Planet(PlanetConfig(**EARTH_SETTINGS))
r1 = np.array([5000, 10000, 2100])
r2 = np.array([-14600, 2500, 7000])
dt = 3600
lambert = vallado2013(mu=earth.mu, r1=r1, r2=r2, tof=dt)
lambert
# Out:
# (array([  2080.48280751, 244715.7621172 , 100525.71406201]),
#  array([ 157047.18480574, -109273.4208579 , -109423.9623325 ]))
