# %%
from mad.objs.common_schemas import MovableObject
import numpy as np

# %%
obj1 = MovableObject(position = [1, 0])
obj2 = MovableObject(position = [0, 1])

# %%
obj1.position, obj1.normalize
# Out:
# (array([1, 0, 0]), array([1., 0., 0.]))

# %%
np.isclose(obj1.distance(obj2), obj2.distance(obj1))
# Out:
# np.True_

# %%
np.isclose(obj1.central_angle(obj2), obj2.central_angle(obj1))
# Out:
# np.True_

# %%
obj1.local_frame(obj2), obj2.local_frame(obj1)
# Out:
# ((array([1., 0., 0.]), array([ 0., -1.,  0.])),
#  (array([0., 1., 0.]), array([-1.,  0.,  0.])))
